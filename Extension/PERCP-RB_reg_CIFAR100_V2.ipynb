# %%
# Usual imports
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from rich.progress import Progress
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# RobustBench
import robustbench
from robustbench.utils import load_model
from secml.utils import fm
from secml import settings

# %% [markdown]
# ## CUDA

# %%
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## Utilities

# %%
class ProbRegressionWrapper(nn.Module):
    def __init__(self, classifier):
        super().__init__()
        self.classifier = classifier  # pretrained classifier

    def forward(self, x):
        logits = self.classifier(x)
        probs = F.softmax(logits, dim=1)
        return probs
    
def load_cifar100_splits(
    n_train=1000,
    n_cal=500,
    n_test=2000
):
    """
    Carica piccoli split (train/cal/test) da CIFAR-100,
    mantenendo la struttura della tua funzione originale.
    """

    transform = T.ToTensor()

    # Load dataset
    trainset = torchvision.datasets.CIFAR100(
        root='./data',
        train=True,
        download=True,
        transform=transform
    )

    # Random permutation of indices
    perm_train = torch.randperm(len(trainset))

    idx_train = perm_train[:n_train]
    idx_cal = perm_train[n_train:n_train+n_cal]
    idx_test = perm_train[n_train+n_cal : n_train+n_cal+n_test]

    # Extract samples
    X_train = torch.stack([trainset[i][0] for i in idx_train])
    y_train = torch.tensor([trainset[i][1] for i in idx_train])

    X_cal = torch.stack([trainset[i][0] for i in idx_cal])
    y_cal = torch.tensor([trainset[i][1] for i in idx_cal])

    X_test = torch.stack([trainset[i][0] for i in idx_test])
    y_test = torch.tensor([trainset[i][1] for i in idx_test])

    print("Loaded CIFAR100 splits:")
    print(f"  Train: {X_train.shape}")
    print(f"  Cal:   {X_cal.shape}")
    print(f"  Test:  {X_test.shape}")

    return (X_train, y_train), (X_cal, y_cal), (X_test, y_test)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### CIFAR_100

# %%
(train_X, train_y), (cal_X, cal_y), (test_X, test_y) = load_cifar100_splits(
    n_train=100, n_cal=50, n_test=50
)

train_X = train_X.to(device)
train_y = train_y.to(device)

cal_X = cal_X.to(device)
cal_y = cal_y.to(device)

test_X = test_X.to(device)
test_y = test_y.to(device)
# Out:
# Loaded CIFAR100 splits:
#   Train: torch.Size([100, 3, 32, 32])
#   Cal:   torch.Size([50, 3, 32, 32])
#   Test:  torch.Size([50, 3, 32, 32])

# %% [markdown]
# ### One-hot encode
# #### (from classification to regression)

# %%
num_classes = 100
train_y_oh = F.one_hot(train_y, num_classes=num_classes).float()
cal_y_oh = F.one_hot(cal_y, num_classes=num_classes).float()
test_y_oh = F.one_hot(test_y, num_classes=num_classes).float()

# %% [markdown]
# ## RobustBench

# %% [markdown]
# ### Regression on Correct-Class Probability
#
# We treat the pretrained classification model as a regressor on the **true-class probability**.
# The regression target is the logit of the true class probability:
#
#
# $$ y_{\text{reg}} = \text{logit}\big(p_{\text{true class}}(x)\big) = \log \frac{p_{\text{true class}}(x)}{1 - p_{\text{true class}}(x)} $$
#
#
# The regressor $ g_\phi(x) $ predicts this real value:
#
# $$
# \hat{y}_{\text{reg}} = g_\phi(x) \approx y_{\text{reg}}
# $$
#
# Performance can be evaluated using MSE on the predicted correct-class probability, classification accuracy, and calibration metrics.

# %%
#L2#
#Wang2023Better_WRN-70-16

#Linf#
#Andriushchenko2020Understanding

# %%
output_dir = fm.join(settings.SECML_MODELS_DIR, 'robustbench')

# %% [markdown]
# ### Load a model

# %%
from robustbench import model_zoo

print("\n---- Available commun corruptions models ----\n")
corruptions_models = model_zoo.cifar100.common_corruptions  # a dict mapping model_name->constructor
print(list(corruptions_models.keys()))

print("\n---- Available Linf models ----\n")
Linf_models = model_zoo.cifar100.linf  # a dict mapping model_name->constructor
print(list(Linf_models.keys()))
# Out:
# ---- Available commun corruptions models ----
#
# ['Diffenderfer2021Winning_LRR', 'Diffenderfer2021Winning_LRR_CARD_Deck', 'Diffenderfer2021Winning_Binary', 'Diffenderfer2021Winning_Binary_CARD_Deck', 'Gowal2020Uncovering_Linf', 'Gowal2020Uncovering_extra_Linf', 'Hendrycks2020AugMix_WRN', 'Hendrycks2020AugMix_ResNeXt', 'Addepalli2021Towards_PARN18', 'Addepalli2021Towards_WRN34', 'Modas2021PRIMEResNet18', 'Addepalli2022Efficient_WRN_34_10']
#
# ---- Available Linf models ----
#
# ['Gowal2020Uncovering', 'Gowal2020Uncovering_extra', 'Cui2020Learnable_34_20_LBGAT6', 'Cui2020Learnable_34_10_LBGAT0', 'Cui2020Learnable_34_10_LBGAT6', 'Chen2020Efficient', 'Wu2020Adversarial', 'Sehwag2021Proxy', 'Sitawarin2020Improving', 'Hendrycks2019Using', 'Rice2020Overfitting', 'Rebuffi2021Fixing_70_16_cutmix_ddpm', 'Rebuffi2021Fixing_28_10_cutmix_ddpm', 'Rebuffi2021Fixing_R18_ddpm', 'Rade2021Helper_R18_ddpm', 'Addepalli2021Towards_PARN18', 'Addepalli2021Towards_WRN34', 'Chen2021LTD_WRN34_10', 'Pang2022Robustness_WRN28_10', 'Pang2022Robustness_WRN70_16', 'Jia2022LAS-AT_34_10', 'Jia2022LAS-AT_34_20', 'Addepalli2022Efficient_RN18', 'Addepalli2022Efficient_WRN_34_10', 'Debenedetti2022Light_XCiT-S12', 'Debenedetti2022Light_XCiT-M12', 'Debenedetti2022Light_XCiT-L12', 'Cui2020Learnable_34_10_LBGAT9_eps_8_255', 'Wang2023Better_WRN-28-10', 'Wang2023Better_WRN-70-16', 'Bai2023Improving_edm', 'Bai2023Improving_trades', 'Cui2023Decoupled_WRN-28-10', 'Cui2023Decoupled_WRN-34-10', 'Cui2023Decoupled_WRN-34-10_autoaug', 'Bai2024MixedNUTS', 'Chen2024Data_WRN_34_10', 'Amini2024MeanSparse_S-WRN-70-16']

# %%
def load_rb_model(model_name, dataset="cifar10", device="cuda" , norm = 'corruptions', model_dir="./models"):
    model = load_model(model_name,dataset=dataset, norm=norm, model_dir=model_dir).to(device)
    return model

# %%
# corruptions
model_names = [
    "Wang2023Better_WRN-70-16",  
    "Cui2020Learnable_34_10_LBGAT0",  
    "Bai2023Improving_trades",  
    "Debenedetti2022Light_XCiT-M12",
    "Rebuffi2021Fixing_28_10_cutmix_ddpm",
    'Addepalli2022Efficient_WRN_34_10',
    'Rice2020Overfitting'
]

# %%
models = {}

for name in model_names:
    print(f"Loading {name}...")
    mdl = load_rb_model(name, 'cifar100', 'cuda','Linf', model_dir=output_dir)
    models[name] = ProbRegressionWrapper(mdl)

print("\nLoaded models:")
print(list(models.keys()))
# Out:
# Loading Wang2023Better_WRN-70-16...
# Loading Cui2020Learnable_34_10_LBGAT0...
# Loading Bai2023Improving_trades...
# The STD classifier has 232647908 parameters. 0 parameters are trainable.
# The ROB classifier has 266888756 parameters. 0 parameters are trainable.
# The mixing network has 67848704 parameters. 67848704 parameters are trainable.
#
# gamma has been set to 1.75, but the mixing network is active so the change is not effective.
# The mixing network's gamma mean is set to 1.0.
# The mixing network's gamma standard deviation is set to 2.0.
# The range of alpha during evaluation is set to (0.8149999976158142, 0.9150000214576721).
# The logit output scale of the STD network is set to 2.0.
# The logit output scale of the ROB network is set to 1.0.
#
# Loading Debenedetti2022Light_XCiT-M12...
# Loading Rebuffi2021Fixing_28_10_cutmix_ddpm...
# Loading Addepalli2022Efficient_WRN_34_10...
# Loading Rice2020Overfitting...
#
# Loaded models:
# ['Wang2023Better_WRN-70-16', 'Cui2020Learnable_34_10_LBGAT0', 'Bai2023Improving_trades', 'Debenedetti2022Light_XCiT-M12', 'Rebuffi2021Fixing_28_10_cutmix_ddpm', 'Addepalli2022Efficient_WRN_34_10', 'Rice2020Overfitting']

# %%
def get_correct_probs(model, X, y):
    with torch.no_grad():
        probs = model(X)                # shape: (n, 10)
        correct_probs = probs[range(len(y)), y]  # shape: (n,)
    return correct_probs.to(device)

# %% [markdown]
# ### Evaluate the model

# %%
def evaluate_model_probs(model, X, y, device, batch_size=128):
    """
    Compute probabilities, correct-class probs, MSE, accuracy for a model.
    """
    model.eval()
    all_probs = []

    with torch.no_grad():
        for i in range(0, len(X), batch_size):
            batch = X[i:i + batch_size].to(device)
            p = model(batch)  # (batch, 10)
            all_probs.append(p)

    probs = torch.cat(all_probs, dim=0)          # (n_samples, 10)
    correct_probs = probs[range(len(y)), y]      # (n_samples,)

    mse = ((correct_probs - 1) ** 2).mean().item()

    preds = probs.argmax(dim=1)
    acc = (preds == y).float().mean().item()

    return probs, correct_probs, mse, acc

# %%
for name, model in models.items():
    print(f"\n========== Evaluating model: {name} ==========")
    probs, correct_probs, mse, acc = evaluate_model_probs(model, test_X, test_y, device)

    print(f"MSE: {mse:.6f}")
    print(f"Accuracy: {acc*100:.2f}%")

    # ----------------------------
    # Plots: Histogram + CDF
    # ----------------------------
    plt.figure(figsize=(12, 5))
    plt.suptitle(f"{name} — Correct-Class Probability Statistics", fontsize=14)

    # Histogram
    plt.subplot(1, 2, 1)
    plt.hist(correct_probs.cpu().numpy(), bins=20, alpha=0.7, color='skyblue')
    plt.title("Histogram of correct-class probabilities")
    plt.xlabel("p(true class | x)")
    plt.ylabel("Count")
    plt.grid(alpha=0.3)

    # CDF
    plt.subplot(1, 2, 2)
    sorted_probs, _ = torch.sort(correct_probs.cpu())
    cdf = torch.arange(1, len(sorted_probs) + 1) / len(sorted_probs)

    plt.plot(sorted_probs.numpy(), cdf.numpy(), color='orange')
    plt.title("Empirical CDF of correct-class probabilities")
    plt.xlabel("p(true class | x)")
    plt.ylabel("CDF")
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()
# Out:
# ========== Evaluating model: Wang2023Better_WRN-70-16 ==========
# MSE: 0.147347
# Accuracy: 98.60%
# ========== Evaluating model: Cui2020Learnable_34_10_LBGAT0 ==========
# MSE: 0.205443
# Accuracy: 86.80%
# ========== Evaluating model: Bai2023Improving_trades ==========
# MSE: 0.080633
# Accuracy: 97.80%
# ========== Evaluating model: Debenedetti2022Light_XCiT-M12 ==========
# MSE: 0.461553
# Accuracy: 86.20%
# ========== Evaluating model: Rebuffi2021Fixing_28_10_cutmix_ddpm ==========
# MSE: 0.321842
# Accuracy: 87.00%
# ========== Evaluating model: Addepalli2022Efficient_WRN_34_10 ==========
# MSE: 0.330016
# Accuracy: 97.60%
# ========== Evaluating model: Rice2020Overfitting ==========
# MSE: 0.061970
# Accuracy: 97.00%

# %% [markdown]
# ## Attack

# %%
# pip install torchattacks
import torchattacks
from autoattack import AutoAttack

class ProbToLogitsWrapper(torch.nn.Module):
    def __init__(self, model_prob):
        super().__init__()
        self.model_prob = model_prob  # il tuo modello che restituisce probabilità

    def forward(self, x):
        probs = self.model_prob(x)           # (B, K)
        logits = torch.log(probs + 1e-12)    # conversione sicura
        return logits

def attack_with_autoattack(model_prob, X, y, eps=8/255, norm='L2', bs=256, device='cuda'):
    model_prob.eval()

    # wrapper veloce
    model_for_attack = ProbToLogitsWrapper(model_prob).to(device)
    model_for_attack.eval()

    X = X.to(device)
    y = y.to(device)

    autoattack = AutoAttack(
        model_for_attack,
        norm=norm,
        eps=eps,
        version='custom',          # per avere un singolo attacco
        attacks_to_run=['apgd-ce'], 
        device=device,
        verbose=True
    )

    # riduci il numero di iterazioni
    autoattack.apgd.n_iter = 10
    
    adversarial_examples = autoattack.run_standard_evaluation(X, y, bs=bs)

    return adversarial_examples

# %%
def fgsm_attack_regression_batched(model, X, y, epsilon=0.05, batch_size=32):
    model.eval()
    X_adv_list = []
    
    for i in range(0, len(X), batch_size):
        xb = X[i:i+batch_size].clone().detach().to(device)
        yb = y[i:i+batch_size].to(device)

        xb.requires_grad = True

        # Forward
        probs = model(xb)  # shape (B,10)
        correct_probs = probs[range(len(yb)), yb]

        # Loss = push correct class prob → 1
        loss = ((correct_probs - 1)**2).mean()

        # Compute gradient
        model.zero_grad()
        loss.backward()

        # FGSM step
        xb_adv = xb + epsilon * xb.grad.sign()
        xb_adv = torch.clamp(xb_adv, 0, 1).detach()

        X_adv_list.append(xb_adv)  # move OFF GPU immediately

        # Free memory
        del xb, yb, probs, correct_probs, loss, xb_adv
        torch.cuda.empty_cache()

    return torch.cat(X_adv_list, dim=0)

# %% [markdown]
# ### Run the attack

# %% [markdown]
# ### L2 ------ $\varepsilon = 0.5$

# %%
eps = 0.5   # AutoAttack tipico
batch_size = 256

adv_data = {}  # qui salviamo i risultati per ogni modello

for model_name, model in models.items():
    print(f"\n========== Generating AutoAttack adversarial data for model: {model_name} ==========")

    # calibration set
    cal_X_adv = attack_with_autoattack(
        model, cal_X, cal_y,
        eps=eps,
        norm='L2',   # o 'Linf'
        bs=batch_size,
        device=device
    )

    # test set
    test_X_adv = attack_with_autoattack(
        model, test_X, test_y,
        eps=eps,
        norm='L2',
        bs=batch_size,
        device=device
    )

    adv_data[model_name] = {
        "cal_X_adv":  cal_X_adv,
        "test_X_adv": test_X_adv
    }

print("\nDone.")
# Out:
# ========== Generating AutoAttack adversarial data for model: Hendrycks2020AugMix_WRN ==========
# using custom version including apgd-ce.
# initial accuracy: 97.90%
# apgd-ce - 1/4 - 254 out of 256 successfully perturbed
# apgd-ce - 2/4 - 251 out of 256 successfully perturbed
# apgd-ce - 3/4 - 254 out of 256 successfully perturbed
# apgd-ce - 4/4 - 208 out of 211 successfully perturbed
# robust accuracy after APGD-CE: 1.20% (total time 3.5 s)
# max L2 perturbation: 0.48802, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 1.20%
# using custom version including apgd-ce.
# initial accuracy: 97.60%
# apgd-ce - 1/2 - 252 out of 256 successfully perturbed
# apgd-ce - 2/2 - 228 out of 232 successfully perturbed
# robust accuracy after APGD-CE: 1.60% (total time 1.6 s)
# max L2 perturbation: 0.48871, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 1.60%
#
# ========== Generating AutoAttack adversarial data for model: Hendrycks2020AugMix_ResNeXt ==========
# using custom version including apgd-ce.
# initial accuracy: 100.00%
# apgd-ce - 1/4 - 255 out of 256 successfully perturbed
# apgd-ce - 2/4 - 253 out of 256 successfully perturbed
# apgd-ce - 3/4 - 254 out of 256 successfully perturbed
# apgd-ce - 4/4 - 232 out of 232 successfully perturbed
# robust accuracy after APGD-CE: 0.60% (total time 6.9 s)
# max L2 perturbation: 0.48730, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 0.60%
# using custom version including apgd-ce.
# initial accuracy: 100.00%
# apgd-ce - 1/2 - 252 out of 256 successfully perturbed
# apgd-ce - 2/2 - 239 out of 244 successfully perturbed
# robust accuracy after APGD-CE: 1.80% (total time 3.5 s)
# max L2 perturbation: 0.48161, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 1.80%
#
# ========== Generating AutoAttack adversarial data for model: Addepalli2021Towards_WRN34 ==========
# using custom version including apgd-ce.
# initial accuracy: 93.50%
# apgd-ce - 1/4 - 58 out of 256 successfully perturbed
# apgd-ce - 2/4 - 55 out of 256 successfully perturbed
# apgd-ce - 3/4 - 42 out of 256 successfully perturbed
# apgd-ce - 4/4 - 32 out of 167 successfully perturbed
# robust accuracy after APGD-CE: 74.80% (total time 26.0 s)
# max L2 perturbation: 0.50000, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 74.80%
# using custom version including apgd-ce.
# initial accuracy: 92.80%
# apgd-ce - 1/2 - 47 out of 256 successfully perturbed
# apgd-ce - 2/2 - 37 out of 208 successfully perturbed
# robust accuracy after APGD-CE: 76.00% (total time 13.1 s)
# max L2 perturbation: 0.50000, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 76.00%
#
# ========== Generating AutoAttack adversarial data for model: Diffenderfer2021Winning_Binary ==========
# using custom version including apgd-ce.
# initial accuracy: 98.60%
# apgd-ce - 1/4 - 251 out of 256 successfully perturbed
# apgd-ce - 2/4 - 251 out of 256 successfully perturbed
# apgd-ce - 3/4 - 252 out of 256 successfully perturbed
# apgd-ce - 4/4 - 214 out of 218 successfully perturbed
# robust accuracy after APGD-CE: 1.80% (total time 2.9 s)
# max L2 perturbation: 0.49913, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 1.80%
# using custom version including apgd-ce.
# initial accuracy: 98.20%
# apgd-ce - 1/2 - 252 out of 256 successfully perturbed
# apgd-ce - 2/2 - 228 out of 235 successfully perturbed
# robust accuracy after APGD-CE: 2.20% (total time 1.5 s)
# max L2 perturbation: 0.49554, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 2.20%
#
# ========== Generating AutoAttack adversarial data for model: Modas2021PRIMEResNet18 ==========
# using custom version including apgd-ce.
# initial accuracy: 96.70%
# apgd-ce - 1/4 - 242 out of 256 successfully perturbed
# apgd-ce - 2/4 - 244 out of 256 successfully perturbed
# apgd-ce - 3/4 - 241 out of 256 successfully perturbed
# apgd-ce - 4/4 - 184 out of 199 successfully perturbed
# robust accuracy after APGD-CE: 5.60% (total time 2.6 s)
# max L2 perturbation: 0.49436, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 5.60%
# using custom version including apgd-ce.
# initial accuracy: 95.60%
# apgd-ce - 1/2 - 242 out of 256 successfully perturbed
# apgd-ce - 2/2 - 204 out of 222 successfully perturbed
# robust accuracy after APGD-CE: 6.40% (total time 1.3 s)
# max L2 perturbation: 0.49644, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 6.40%
#
# ========== Generating AutoAttack adversarial data for model: Addepalli2022Efficient_WRN_34_10 ==========
# using custom version including apgd-ce.
# initial accuracy: 97.50%
# apgd-ce - 1/4 - 24 out of 256 successfully perturbed
# apgd-ce - 2/4 - 20 out of 256 successfully perturbed
# apgd-ce - 3/4 - 20 out of 256 successfully perturbed
# apgd-ce - 4/4 - 15 out of 207 successfully perturbed
# robust accuracy after APGD-CE: 89.60% (total time 30.1 s)
# max L2 perturbation: 0.50000, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 89.60%
# using custom version including apgd-ce.
# initial accuracy: 98.00%
# apgd-ce - 1/2 - 17 out of 256 successfully perturbed
# apgd-ce - 2/2 - 20 out of 234 successfully perturbed
# robust accuracy after APGD-CE: 90.60% (total time 15.3 s)
# max L2 perturbation: 0.50000, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 90.60%
#
# ========== Generating AutoAttack adversarial data for model: Gowal2020Uncovering_Linf ==========
# using custom version including apgd-ce.
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[43], line 10
#       7 print(f"\n========== Generating AutoAttack adversarial data for model: {model_name} ==========")
#       9 # calibration set
# ---> 10 cal_X_adv = attack_with_autoattack(
#      11     model, cal_X, cal_y,
#      12     eps=eps,
#      13     norm='L2',   # o 'Linf'
#      14     bs=batch_size,
#      15     device=device
#      16 )
#      18 # test set
#      19 test_X_adv = attack_with_autoattack(
#      20     model, test_X, test_y,
#      21     eps=eps,
#    (...)
#      24     device=device
#      25 )
#
# Cell In[42], line 38, in attack_with_autoattack(model_prob, X, y, eps, norm, bs, device)
#      35 # riduci il numero di iterazioni
#      36 autoattack.apgd.n_iter = 10
# ---> 38 adversarial_examples = autoattack.run_standard_evaluation(X, y, bs=bs)
#      40 return adversarial_examples
#
# File ~/.local/lib/python3.10/site-packages/autoattack/autoattack.py:116, in AutoAttack.run_standard_evaluation(self, x_orig, y_orig, bs, return_labels, state_path)
#     112     checks.check_randomized(self.get_logits, x_orig[:bs].to(self.device),
#     113         y_orig[:bs].to(self.device), bs=bs, logger=self.logger)
#     114 n_cls = checks.check_range_output(self.get_logits, x_orig[:bs].to(self.device),
#     115     logger=self.logger)
# --> 116 checks.check_dynamic(self.model, x_orig[:bs].to(self.device), self.is_tf_model,
#     117     logger=self.logger)
#     118 checks.check_n_classes(n_cls, self.attacks_to_run, self.apgd_targeted.n_target_classes,
#     119     self.fab.n_target_classes, logger=self.logger)
#     121 with torch.no_grad():
#     122     # calculate accuracy
#
# File ~/.local/lib/python3.10/site-packages/autoattack/checks.py:101, in check_dynamic(model, x, is_tf_model, logger)
#      99 msg = None
#     100 sys.settrace(tracefunc)
# --> 101 model(x)
#     102 sys.settrace(None)
#     103 #for k, v in funcs.items():
#     104 #    print(k, v)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[42], line 11, in ProbToLogitsWrapper.forward(self, x)
#      10 def forward(self, x):
# ---> 11     probs = self.model_prob(x)           # (B, K)
#      12     logits = torch.log(probs + 1e-12)    # conversione sicura
#      13     return logits
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[3], line 7, in ProbRegressionWrapper.forward(self, x)
#       6 def forward(self, x):
# ----> 7     logits = self.classifier(x)
#       8     probs = F.softmax(logits, dim=1)
#       9     return probs
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/robustbench/model_zoo/architectures/dm_wide_resnet.py:190, in DMWideResNet.forward(self, x)
#     188 out = (x - self.mean) / self.std
#     189 out = self.init_conv(out)
# --> 190 out = self.layer(out)
#     191 out = self.relu(self.batchnorm(out))
#     192 out = F.avg_pool2d(out, 8)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/robustbench/model_zoo/architectures/dm_wide_resnet.py:132, in _BlockGroup.forward(self, x)
#     131 def forward(self, x):
# --> 132     return self.block(x)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/robustbench/model_zoo/architectures/dm_wide_resnet.py:106, in _Block.forward(self, x)
#     104     raise ValueError('Unsupported `stride`.')
#     105 out = self.conv_0(v)
# --> 106 out = self.relu_1(self.batchnorm_1(out))
#     107 out = self.conv_1(out)
#     108 out = torch.add(self.shortcut(x) if self.has_shortcut else x, out)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/robustbench/model_zoo/architectures/dm_wide_resnet.py:51, in Swish.forward(self, input_tensor)
#      50 def forward(self, input_tensor):
# ---> 51     return _Swish.apply(input_tensor)
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/.local/lib/python3.10/site-packages/robustbench/model_zoo/architectures/dm_wide_resnet.py:36, in _Swish.forward(ctx, i)
#      34 @staticmethod
#      35 def forward(ctx, i):
# ---> 36     result = i * torch.sigmoid(i)
#      37     ctx.save_for_backward(i)
#      38     return result
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 23.53 GiB of which 71.62 MiB is free. Process 1267427 has 23.45 GiB memory in use. Of the allocated memory 21.57 GiB is allocated by PyTorch, and 1.41 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ### Linf ------ $\varepsilon = 8/255$

# %%
eps = 8/255   # AutoAttack tipico
batch_size = 32

adv_data = {}  # qui salviamo i risultati per ogni modello

for model_name, model in models.items():
    print(f"\n========== Generating AutoAttack adversarial data for model: {model_name} ==========")

    # calibration set
    cal_X_adv = attack_with_autoattack(
        model, cal_X, cal_y,
        eps=eps,
        norm='Linf',   # o 'Linf'
        bs=batch_size,
        device=device
    )

    # test set
    test_X_adv = attack_with_autoattack(
        model, test_X, test_y,
        eps=eps,
        norm='Linf',
        bs=batch_size,
        device=device
    )

    adv_data[model_name] = {
        "cal_X_adv":  cal_X_adv,
        "test_X_adv": test_X_adv
    }

print("\nDone.")
# Out:
# ========== Generating AutoAttack adversarial data for model: Wang2023Better_WRN-70-16 ==========
# using custom version including apgd-ce.
# initial accuracy: 100.00%
# apgd-ce - 1/2 - 1 out of 32 successfully perturbed
# apgd-ce - 2/2 - 2 out of 18 successfully perturbed
# robust accuracy after APGD-CE: 94.00% (total time 7.5 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 94.00%
# using custom version including apgd-ce.
# initial accuracy: 100.00%
# apgd-ce - 1/2 - 0 out of 32 successfully perturbed
# apgd-ce - 2/2 - 1 out of 18 successfully perturbed
# robust accuracy after APGD-CE: 98.00% (total time 8.1 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 98.00%
#
# ========== Generating AutoAttack adversarial data for model: Cui2020Learnable_34_10_LBGAT0 ==========
# using custom version including apgd-ce.
# initial accuracy: 88.00%
# apgd-ce - 1/2 - 5 out of 32 successfully perturbed
# apgd-ce - 2/2 - 10 out of 12 successfully perturbed
# robust accuracy after APGD-CE: 58.00% (total time 1.8 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 58.00%
# using custom version including apgd-ce.
# initial accuracy: 94.00%
# apgd-ce - 1/2 - 13 out of 32 successfully perturbed
# apgd-ce - 2/2 - 8 out of 15 successfully perturbed
# robust accuracy after APGD-CE: 52.00% (total time 1.6 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 52.00%
#
# ========== Generating AutoAttack adversarial data for model: Bai2023Improving_trades ==========
# using custom version including apgd-ce.
# initial accuracy: 98.00%
# apgd-ce - 1/2 - 3 out of 32 successfully perturbed
# apgd-ce - 2/2 - 4 out of 17 successfully perturbed
# robust accuracy after APGD-CE: 84.00% (total time 18.0 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 84.00%
# using custom version including apgd-ce.
# initial accuracy: 98.00%
# apgd-ce - 1/2 - 1 out of 32 successfully perturbed
# apgd-ce - 2/2 - 1 out of 17 successfully perturbed
# robust accuracy after APGD-CE: 94.00% (total time 18.4 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 94.00%
#
# ========== Generating AutoAttack adversarial data for model: Debenedetti2022Light_XCiT-M12 ==========
# using custom version including apgd-ce.
# initial accuracy: 88.00%
# apgd-ce - 1/2 - 6 out of 32 successfully perturbed
# apgd-ce - 2/2 - 6 out of 12 successfully perturbed
# robust accuracy after APGD-CE: 64.00% (total time 6.1 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 64.00%
# using custom version including apgd-ce.
# initial accuracy: 92.00%
# apgd-ce - 1/2 - 4 out of 32 successfully perturbed
# apgd-ce - 2/2 - 4 out of 14 successfully perturbed
# robust accuracy after APGD-CE: 76.00% (total time 6.1 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 76.00%
#
# ========== Generating AutoAttack adversarial data for model: Rebuffi2021Fixing_28_10_cutmix_ddpm ==========
# using custom version including apgd-ce.
# initial accuracy: 86.00%
# apgd-ce - 1/2 - 3 out of 32 successfully perturbed
# apgd-ce - 2/2 - 5 out of 11 successfully perturbed
# robust accuracy after APGD-CE: 70.00% (total time 2.2 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 70.00%
# using custom version including apgd-ce.
# initial accuracy: 92.00%
# apgd-ce - 1/2 - 6 out of 32 successfully perturbed
# apgd-ce - 2/2 - 3 out of 14 successfully perturbed
# robust accuracy after APGD-CE: 74.00% (total time 2.1 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 74.00%
#
# ========== Generating AutoAttack adversarial data for model: Addepalli2022Efficient_WRN_34_10 ==========
# using custom version including apgd-ce.
# initial accuracy: 98.00%
# apgd-ce - 1/2 - 3 out of 32 successfully perturbed
# apgd-ce - 2/2 - 5 out of 17 successfully perturbed
# robust accuracy after APGD-CE: 82.00% (total time 1.9 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 82.00%
# using custom version including apgd-ce.
# initial accuracy: 98.00%
# apgd-ce - 1/2 - 1 out of 32 successfully perturbed
# apgd-ce - 2/2 - 3 out of 17 successfully perturbed
# robust accuracy after APGD-CE: 90.00% (total time 1.9 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 90.00%
#
# ========== Generating AutoAttack adversarial data for model: Rice2020Overfitting ==========
# using custom version including apgd-ce.
# initial accuracy: 98.00%
# apgd-ce - 1/2 - 3 out of 32 successfully perturbed
# apgd-ce - 2/2 - 8 out of 17 successfully perturbed
# robust accuracy after APGD-CE: 76.00% (total time 0.9 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 76.00%
# using custom version including apgd-ce.
# initial accuracy: 98.00%
# apgd-ce - 1/2 - 5 out of 32 successfully perturbed
# apgd-ce - 2/2 - 2 out of 17 successfully perturbed
# robust accuracy after APGD-CE: 84.00% (total time 1.0 s)
# max Linf perturbation: 0.03137, nan in tensor: 0, max: 1.00000, min: 0.00000
# robust accuracy: 84.00%
#
# Done.

# %% [markdown]
# ### Post-attack evaluation

# %%
batch_size = 128

results_post_attack = {}

for model_name, model in models.items():
    print(f"\n========== Post-attack evaluation for model: {model_name} ==========")

    model.eval()
    test_X_adv = adv_data[model_name]["test_X_adv"]

    # -----------------------------
    # Forward pass adversarial
    # -----------------------------
    all_probs_adv = []
    with torch.no_grad():
        for i in range(0, len(test_X_adv), batch_size):
            batch = test_X_adv[i:i+batch_size].to(device)
            p = model(batch)
            all_probs_adv.append(p)

    probs_adv = torch.cat(all_probs_adv, dim=0)

    # -----------------------------
    # Pre-attack probs (calcoliamole se non le hai salvate)
    # -----------------------------
    all_probs_clean = []
    with torch.no_grad():
        for i in range(0, len(test_X), batch_size):
            batch = test_X[i:i+batch_size].to(device)
            p = model(batch)
            all_probs_clean.append(p)

    probs_clean = torch.cat(all_probs_clean, dim=0)

    # Correct class probabilities
    correct_probs_clean = probs_clean[range(len(test_y)), test_y]
    correct_probs_adv   = probs_adv[range(len(test_y)), test_y]

    # -----------------------------
    # MSE
    # -----------------------------
    mse_adv = ((correct_probs_adv - 1)**2).mean().item()
    mse_clean = ((correct_probs_clean - 1)**2).mean().item()

    print(f"MSE (clean): {mse_clean:.6f}")
    print(f"MSE after attack: {mse_adv:.6f}")

    # -----------------------------
    # Accuracy
    # -----------------------------
    preds_clean = probs_clean.argmax(dim=1)
    preds_adv   = probs_adv.argmax(dim=1)

    acc_clean = (preds_clean == test_y.to(device)).float().mean().item()
    acc_adv   = (preds_adv == test_y.to(device)).float().mean().item()

    print(f"Accuracy (clean): {acc_clean*100:.2f}%")
    print(f"Accuracy after attack: {acc_adv*100:.2f}%")

    # -----------------------------
    # Pre and Post Attack CDFs
    # -----------------------------
    sorted_probs_pre  = np.sort(correct_probs_clean.cpu().numpy())
    sorted_probs_post = np.sort(correct_probs_adv.cpu().numpy())

    cdf_pre  = np.arange(1, len(sorted_probs_pre)+1)  / len(sorted_probs_pre)
    cdf_post = np.arange(1, len(sorted_probs_post)+1) / len(sorted_probs_post)

    # -----------------------------
    # PLOT
    # -----------------------------
    fig = plt.figure(figsize=(14, 10))
    gs = GridSpec(2, 2, figure=fig, height_ratios=[1, 1])

    # Histogram before
    ax0 = fig.add_subplot(gs[0, 0])
    ax0.hist(correct_probs_clean.cpu().numpy(), bins=20, alpha=0.7, color='blue')
    ax0.set_title(f"Histogram Before Attack – {model_name}")
    ax0.set_xlabel("p(true class | x)")
    ax0.set_ylabel("Count")
    ax0.grid(alpha=0.3)

    # Histogram after
    ax1 = fig.add_subplot(gs[0, 1])
    ax1.hist(correct_probs_adv.cpu().numpy(), bins=20, alpha=0.7, color='orange')
    ax1.set_title(f"Histogram After Attack – {model_name}")
    ax1.set_xlabel("p(true class | x)")
    ax1.set_ylabel("Count")
    ax1.grid(alpha=0.3)

    # CDF comparison
    ax2 = fig.add_subplot(gs[1, :])
    ax2.plot(sorted_probs_pre, cdf_pre, color='blue', linewidth=2, label='Before Attack')
    ax2.plot(sorted_probs_post, cdf_post, color='red',  linewidth=2, label='After Attack')
    ax2.set_title(f"CDF Comparison – {model_name}")
    ax2.set_xlabel("p(true class | x)")
    ax2.set_ylabel("CDF")
    ax2.grid(alpha=0.3)
    ax2.legend()

    plt.tight_layout()
    plt.show()

    # Save results
    results_post_attack[model_name] = {
        "mse_clean": mse_clean,
        "mse_adv": mse_adv,
        "acc_clean": acc_clean,
        "acc_adv": acc_adv,
        "correct_probs_clean": correct_probs_clean,
        "correct_probs_adv": correct_probs_adv,
    }

# %% [markdown]
# ## CP SEI ARRIVATO QUI !!!

# %%
def nonconformity_score(y_true, y_pred, u=None):
    """
    Compute nonconformity scores for regression CP, optionally using an uncertainty scalar.

    Args:
        y_true: torch.Tensor of shape (n,)  -- true regression targets
        y_pred: torch.Tensor of shape (n,)  -- predicted regression outputs
        u: torch.Tensor of shape (n,), optional -- per-example uncertainty (e.g., predicted std or residual)
    
    Returns:
        scores: torch.Tensor of shape (n,)  -- nonconformity scores
    """
    residuals = torch.abs(y_pred - y_true)
    
    if u is not None:
        scores = residuals / u
        
    else:
        scores = residuals
    
    return scores

# %%
def cp_interval_width(u, qhat):
    """
    Computes conformal prediction interval widths.
    
    Args:
        u:    array-like of shape (n,) -- uncertainty scalar u(x)
        qhat: float                   -- conformal quantile

    Returns:
        width: array of shape (n,) -- interval widths
    """
    u = torch.as_tensor(u, dtype=torch.float32)
    return 2 * u * qhat

# %%
def extract_scores(models,
                   cal_X, cal_y,
                   test_X, test_y,
                   datamode="clean"):
    """
    Estrarre score, predizioni e u dal calibration e test set.
    Può lavorare sia su dati clean sia attaccati.

    Args:
        models: dict {name: model}
        cal_X, cal_y: calibration data
        test_X, test_y: test data
        datamode: "clean" oppure "adv"

    Returns:
        results: dict con per-modello:
            probs_cal, y_pred_cal, u_cal, score_cal
            probs_test, y_pred_test, u_test, score_test
    """

    results = {}

    with torch.no_grad():
        for name, model in models.items():
            print(f"\n=== Processing model: {name} ({datamode}) ===")

            # -----------------------------
            # Calibrazione
            # -----------------------------
            probs_cal = model(cal_X)
            y_pred_cal = probs_cal[range(len(cal_y)), cal_y]

            #u_cal = ((y_pred_cal - 1) ** 2)#.mean().item()
            #epsilon = 1e-6
            #u_cal = torch.sqrt((y_pred_cal - 1) ** 2 + epsilon)
            
            residuals = torch.abs(y_pred_cal - 1)  # shape (n_cal,)
            residuals_reshaped = residuals.unsqueeze(0).unsqueeze(0)  # shape (1,1,n_cal)

            # Apply a 1D average pooling with kernel size 5
            smoothed_residuals = F.avg_pool1d(residuals_reshaped, kernel_size=5, stride=1, padding=2)
            u_cal = smoothed_residuals.squeeze()
            
            score_cal = nonconformity_score(
                1.0,
                y_pred_cal.float(),
                u=u_cal
            )

            # -----------------------------
            # Test
            # -----------------------------
            probs_test = model(test_X)
            y_pred_test = probs_test[range(len(test_y)), test_y]

            #u_test = ((y_pred_test - 1) ** 2)#.mean().item()
            #u_test = torch.sqrt((y_pred_test - 1) ** 2 + epsilon)
            residuals = torch.abs(y_pred_test - 1)  # shape (n_cal,)
            residuals_reshaped = residuals.unsqueeze(0).unsqueeze(0)  # shape (1,1,n_cal)

            # Apply a 1D average pooling with kernel size 5
            smoothed_residuals = F.avg_pool1d(residuals_reshaped, kernel_size=5, stride=1, padding=2)
            u_test = smoothed_residuals.squeeze()
            
            score_test = nonconformity_score(
                1.0,
                y_pred_test.float(),
                u=u_test
            )

            # -----------------------------
            # Salvataggio
            # -----------------------------
            results[name] = {
                "probs_cal": probs_cal,
                "y_pred_cal": y_pred_cal,
                "u_cal": u_cal,
                "score_cal": score_cal,

                "probs_test": probs_test,
                "y_pred_test": y_pred_test,
                "u_test": u_test,
                "score_test": score_test,
            }

    return results

# %%
def plot_scores_for_all_models(results):
    
    for name, data in results.items():
        print(f"\n=== Plotting for model: {name} ===")
        
        score_cal = data["score_cal"]
        score_test = data["score_test"]

        # Convert to numpy
        score_cal_np = score_cal.cpu().numpy() if hasattr(score_cal, "cpu") else np.array(score_cal)
        score_test_np = score_test.cpu().numpy() if hasattr(score_test, "cpu") else np.array(score_test)

        # Create figure
        plt.figure(figsize=(16, 5))
        plt.suptitle(f"Nonconformity Scores – {name}", fontsize=16)

        # -------------------------
        # 1. Histogram
        # -------------------------
        plt.subplot(1, 3, 1)
        plt.hist(score_cal_np, bins=30, alpha=0.6, label="Calibration", color='blue')
        plt.hist(score_test_np, bins=30, alpha=0.6, label="Test", color='orange')
        plt.title("Histogram of Scores")
        plt.xlabel("Score")
        plt.ylabel("Frequency")
        plt.legend()

        # -------------------------
        # 2. Boxplot
        # -------------------------
        plt.subplot(1, 3, 2)
        plt.boxplot([score_cal_np, score_test_np], labels=["Calibration", "Test"])
        plt.title("Boxplot of Scores")
        plt.ylabel("Score")

        # -------------------------
        # 3. Empirical CDF
        # -------------------------
        plt.subplot(1, 3, 3)
        sorted_cal = np.sort(score_cal_np)
        sorted_test = np.sort(score_test_np)
        cdf_cal = np.arange(1, len(sorted_cal)+1) / len(sorted_cal)
        cdf_test = np.arange(1, len(sorted_test)+1) / len(sorted_test)

        plt.plot(sorted_cal, cdf_cal, label="Calibration", color='blue', linewidth=2)
        plt.plot(sorted_test, cdf_test, label="Test", color='orange', linewidth=2)

        plt.title("Empirical CDF of Scores")
        plt.xlabel("Score")
        plt.ylabel("CDF")
        plt.grid(alpha=0.3)
        plt.legend()

        plt.tight_layout()
        plt.show()

# %%
def _to_numpy(x):
    if isinstance(x, torch.Tensor):
        return x.detach().cpu().numpy()
    return np.array(x)

# %%
def compute_cp(
    clean_results, 
    adv_results, 
    alpha=0.1, 
    cal_on='clean',     # calibrazione su 'clean' o 'adv'
    eval_on='clean',    # dataset su cui calcolare coverage
    interval_on='test'  # 'test' oppure 'cal'
):
    """
    Calcola CP in modo flessibile.

    clean_results: dizionario score clean
    adv_results:   dizionario score avversari
    cal_on:        set per calibrazione ('clean' o 'adv')
    eval_on:       set per coverage ('clean' o 'adv')
    interval_on:   set su cui costruire gli intervalli ('cal' o 'test')
    """
    
    cp_outputs = {}
    
    for name in clean_results.keys():
        print(f"\n--- CP for model: {name} | Cal: {cal_on} | Eval: {eval_on} | Interval: {interval_on} ---")
        
        clean = clean_results[name]
        adv   = adv_results[name]

        # -------------------------
        # STEP 1 — Calibrazione
        # -------------------------
        source_cal = clean if cal_on=='clean' else adv

        score_cal = _to_numpy(source_cal["score_cal"])
        y_pred_cal = _to_numpy(source_cal["y_pred_cal"]).astype(np.float32)
        u_cal = _to_numpy(source_cal["u_cal"])

        n_cal = len(score_cal)
        q_level = np.floor((n_cal + 1) * (1 - alpha)) / n_cal
        qhat = float(
            torch.quantile(torch.tensor(score_cal, dtype=torch.float32), float(q_level))
        )

        print(f" q̂ (CP): {qhat:.6f}")

        # -------------------------
        # STEP 2 — Scegli set per intervalli
        # -------------------------
        if interval_on == 'test':
            y_pred_interval = clean["y_pred_test"] if eval_on=='clean' else adv["y_pred_test"]
            u_interval      = clean["u_test"]      if cal_on=='clean' else adv["u_test"]
        elif interval_on == 'cal':
            y_pred_interval = clean["y_pred_cal"] if eval_on=='clean' else adv["y_pred_cal"]
            u_interval      = clean["u_cal"]      if cal_on=='clean' else adv["u_cal"]
        else:
            raise ValueError("interval_on must be 'cal' or 'test'")
        
        
        y_pred_eval = _to_numpy(y_pred_interval).astype(np.float32)
        u_eval      = _to_numpy(u_interval)
                
        # -------------------------
        # STEP 3 — Coverage (sempre sul test o cal, deciso da eval_on)
        # -------------------------

        y_true_eval = np.ones_like(y_pred_eval, dtype=np.float32)

        # -------------------------
        # STEP 4 — Costruisci intervalli
        # -------------------------
        radius = qhat * u_eval
        lower  = y_pred_eval - radius
        upper  = y_pred_eval + radius

        coverage = float(np.mean((lower <= y_true_eval) & (y_true_eval <= upper)))
        mean_width = float(np.mean(upper - lower))

        print(f" Coverage: {coverage*100:.2f}%")
        print(f" Mean interval width: {mean_width:.6f}")

        cp_outputs[name] = {
            "qhat": qhat,
            "coverage": coverage,
            "mean_width": mean_width,
            "lower": lower,
            "upper": upper,
            "y_pred_interval": y_pred_interval,
            "u_interval": u_interval,
            "cal_on": cal_on,
            "eval_on": eval_on,
            "interval_on": interval_on,
        }

    return cp_outputs

# %%
clean_results = extract_scores(
    models,
    cal_X, cal_y,
    test_X, test_y,
    datamode="clean"
)
# Out:
# === Processing model: Wang2023Better_WRN-70-16 (clean) ===
#
# === Processing model: Cui2020Learnable_34_10_LBGAT0 (clean) ===
#
# === Processing model: Bai2023Improving_trades (clean) ===
#
# === Processing model: Debenedetti2022Light_XCiT-M12 (clean) ===
#
# === Processing model: Rebuffi2021Fixing_28_10_cutmix_ddpm (clean) ===
#
# === Processing model: Addepalli2022Efficient_WRN_34_10 (clean) ===
#
# === Processing model: Rice2020Overfitting (clean) ===

# %%
plot_scores_for_all_models(clean_results)
# Out:
# === Plotting for model: Wang2023Better_WRN-70-16 ===
# === Plotting for model: Cui2020Learnable_34_10_LBGAT0 ===
# === Plotting for model: Bai2023Improving_trades ===
# === Plotting for model: Debenedetti2022Light_XCiT-M12 ===
# === Plotting for model: Rebuffi2021Fixing_28_10_cutmix_ddpm ===
# === Plotting for model: Addepalli2022Efficient_WRN_34_10 ===
# === Plotting for model: Rice2020Overfitting ===

# %%
adv_results = extract_scores(
    models,
    cal_X_adv, cal_y,
    test_X_adv, test_y,
    datamode="adv"
)
# Out:
# === Processing model: Wang2023Better_WRN-70-16 (adv) ===
#
# === Processing model: Cui2020Learnable_34_10_LBGAT0 (adv) ===
#
# === Processing model: Bai2023Improving_trades (adv) ===
#
# === Processing model: Debenedetti2022Light_XCiT-M12 (adv) ===
#
# === Processing model: Rebuffi2021Fixing_28_10_cutmix_ddpm (adv) ===
#
# === Processing model: Addepalli2022Efficient_WRN_34_10 (adv) ===
#
# === Processing model: Rice2020Overfitting (adv) ===

# %%
plot_scores_for_all_models(adv_results)
# Out:
# === Plotting for model: Wang2023Better_WRN-70-16 ===
# === Plotting for model: Cui2020Learnable_34_10_LBGAT0 ===
# === Plotting for model: Bai2023Improving_trades ===
# === Plotting for model: Debenedetti2022Light_XCiT-M12 ===
# === Plotting for model: Rebuffi2021Fixing_28_10_cutmix_ddpm ===
# === Plotting for model: Addepalli2022Efficient_WRN_34_10 ===
# === Plotting for model: Rice2020Overfitting ===

# %%
vanilla_cp_test = compute_cp(clean_results, adv_results, alpha=0.1, cal_on='clean', eval_on='adv', interval_on='test' )
adv_cp_test = compute_cp(clean_results, adv_results, alpha=0.1,cal_on='adv', eval_on='adv', interval_on='test')
# Out:
# --- CP for model: Wang2023Better_WRN-70-16 | Cal: clean | Eval: adv | Interval: test ---
#  q̂ (CP): 1.894017
#  Coverage: 94.00%
#  Mean interval width: 1.006428
#
# --- CP for model: Cui2020Learnable_34_10_LBGAT0 | Cal: clean | Eval: adv | Interval: test ---
#  q̂ (CP): 3.000849
#  Coverage: 90.00%
#  Mean interval width: 1.310062
#
# --- CP for model: Bai2023Improving_trades | Cal: clean | Eval: adv | Interval: test ---
#  q̂ (CP): 2.258589
#  Coverage: 90.00%
#  Mean interval width: 0.556682
#
# --- CP for model: Debenedetti2022Light_XCiT-M12 | Cal: clean | Eval: adv | Interval: test ---
#  q̂ (CP): 1.630966
#  Coverage: 90.00%
#  Mean interval width: 1.805015
#
# --- CP for model: Rebuffi2021Fixing_28_10_cutmix_ddpm | Cal: clean | Eval: adv | Interval: test ---
#  q̂ (CP): 1.694109
#  Coverage: 86.00%
#  Mean interval width: 1.426915
#
# --- CP for model: Addepalli2022Efficient_WRN_34_10 | Cal: clean | Eval: adv | Interval: test ---
#  q̂ (CP): 1.603741
#  Coverage: 90.00%
#  Mean interval width: 1.444479
#
# --- CP for model: Rice2020Overfitting | Cal: clean | Eval: adv | Interval: test ---
#  q̂ (CP): 2.961003
#  Coverage: 86.00%
#  Mean interval width: 0.369981
#
# --- CP for model: Wang2023Better_WRN-70-16 | Cal: adv | Eval: adv | Interval: test ---
#  q̂ (CP): 1.894017
#  Coverage: 96.00%
#  Mean interval width: 1.029751
#
# --- CP for model: Cui2020Learnable_34_10_LBGAT0 | Cal: adv | Eval: adv | Interval: test ---
#  q̂ (CP): 2.698312
#  Coverage: 88.00%
#  Mean interval width: 1.324810
#
# --- CP for model: Bai2023Improving_trades | Cal: adv | Eval: adv | Interval: test ---
#  q̂ (CP): 2.304515
#  Coverage: 90.00%
#  Mean interval width: 0.605640
#
# --- CP for model: Debenedetti2022Light_XCiT-M12 | Cal: adv | Eval: adv | Interval: test ---
#  q̂ (CP): 1.630966
#  Coverage: 90.00%
#  Mean interval width: 1.823973
#
# --- CP for model: Rebuffi2021Fixing_28_10_cutmix_ddpm | Cal: adv | Eval: adv | Interval: test ---
#  q̂ (CP): 1.694109
#  Coverage: 86.00%
#  Mean interval width: 1.458395
#
# --- CP for model: Addepalli2022Efficient_WRN_34_10 | Cal: adv | Eval: adv | Interval: test ---
#  q̂ (CP): 1.644259
#  Coverage: 94.00%
#  Mean interval width: 1.515296
#
# --- CP for model: Rice2020Overfitting | Cal: adv | Eval: adv | Interval: test ---
#  q̂ (CP): 2.663494
#  Coverage: 86.00%
#  Mean interval width: 0.718421

# %%
vanilla_cp_cal = compute_cp(clean_results, adv_results, alpha=0.1, cal_on='clean', eval_on='adv', interval_on='cal' )
adv_cp_cal = compute_cp(clean_results, adv_results, alpha=0.1,cal_on='adv', eval_on='adv', interval_on='cal')
# Out:
# --- CP for model: Hendrycks2020AugMix_WRN | Cal: clean | Eval: adv | Interval: cal ---
#  q̂ (CP): 3.305516
#  Coverage: 12.20%
#  Mean interval width: 0.436423
#
# --- CP for model: Hendrycks2020AugMix_ResNeXt | Cal: clean | Eval: adv | Interval: cal ---
#  q̂ (CP): 3.187503
#  Coverage: 8.10%
#  Mean interval width: 0.018569
#
# --- CP for model: Addepalli2021Towards_WRN34 | Cal: clean | Eval: adv | Interval: cal ---
#  q̂ (CP): 1.422999
#  Coverage: 83.90%
#  Mean interval width: 1.791561
#
# --- CP for model: Diffenderfer2021Winning_Binary | Cal: clean | Eval: adv | Interval: cal ---
#  q̂ (CP): 2.718315
#  Coverage: 10.10%
#  Mean interval width: 0.456963
#
# --- CP for model: Modas2021PRIMEResNet18 | Cal: clean | Eval: adv | Interval: cal ---
#  q̂ (CP): 1.367701
#  Coverage: 2.50%
#  Mean interval width: 1.495049
#
# --- CP for model: Hendrycks2020AugMix_WRN | Cal: adv | Eval: adv | Interval: cal ---
#  q̂ (CP): 1.470478
#  Coverage: 90.00%
#  Mean interval width: 2.310962
#
# --- CP for model: Hendrycks2020AugMix_ResNeXt | Cal: adv | Eval: adv | Interval: cal ---
#  q̂ (CP): 1.660679
#  Coverage: 90.00%
#  Mean interval width: 2.305137
#
# --- CP for model: Addepalli2021Towards_WRN34 | Cal: adv | Eval: adv | Interval: cal ---
#  q̂ (CP): 1.357542
#  Coverage: 90.00%
#  Mean interval width: 1.878631
#
# --- CP for model: Diffenderfer2021Winning_Binary | Cal: adv | Eval: adv | Interval: cal ---
#  q̂ (CP): 1.427728
#  Coverage: 90.00%
#  Mean interval width: 2.217828
#
# --- CP for model: Modas2021PRIMEResNet18 | Cal: adv | Eval: adv | Interval: cal ---
#  q̂ (CP): 1.020978
#  Coverage: 90.00%
#  Mean interval width: 2.012005
